# %% [markdown]
# Tech Project 2 - Ensemble Methods
#
# Diogo Pessoa

# %%
import pandas as pd

# %%
combined_data=pd.read_csv('combined_data.csv').set_index('video_id')
label = combined_data['label']
features = combined_data.drop(['label'],axis=1)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154567 entries, kzwfHumJyYc to ooyjaVdt-jA
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   comments_disabled               154567 non-null  bool
#  1   ratings_disabled                154567 non-null  bool
#  2   video_error_or_removed          154567 non-null  bool
#  3   likes_log                       154567 non-null  float64
#  4   label                           154567 non-null  float64
#  5   dislikes_log                    154567 non-null  float64
#  6   comment_log                     154567 non-null  float64
#  7   num_tags                        154567 non-null  int64
#  8   desc_len                        154567 non-null  int64
#  9   len_title                       154567 non-null  int64
#  10  country_CA                      154567 non-null  bool
#  11  country_FR                      154567 non-null  bool
#  12  country_IN                      154567 non-null  bool
#  13  country_US                      154567 non-null  bool
#  14  category_Autos & Vehicles       154567 non-null  bool
#  15  category_Comedy                 154567 non-null  bool
#  16  category_Education              154567 non-null  bool
#  17  category_Entertainment          154567 non-null  bool
#  18  category_Film & Animation       154567 non-null  bool
#  19  category_Gaming                 154567 non-null  bool
#  20  category_Howto & Style          154567 non-null  bool
#  21  category_Movies                 154567 non-null  bool
#  22  category_Music                  154567 non-null  bool
#  23  category_News & Politics        154567 non-null  bool
#  24  category_Nonprofits & Activism  154567 non-null  bool
#  25  category_People & Blogs         154567 non-null  bool
#  26  category_Pets & Animals         154567 non-null  bool
#  27  category_Science & Technology   154567 non-null  bool
#  28  category_Shows                  154567 non-null  bool
#  29  category_Sports                 154567 non-null  bool
#  30  category_Trailers               154567 non-null  bool
#  31  category_Travel & Events        154567 non-null  bool
#  32  publish_weekday_1               154567 non-null  bool
#  33  publish_weekday_2               154567 non-null  bool
#  34  publish_weekday_3               154567 non-null  bool
#  35  publish_weekday_4               154567 non-null  bool
#  36  publish_weekday_5               154567 non-null  bool
#  37  publish_weekday_6               154567 non-null  bool
#  38  publish_weekday_7               154567 non-null  bool
# dtypes: bool(32), float64(4), int64(3)
# memory usage: 14.2+ MB

# %%
combined_data.head(25)
# Out:
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# video_id
# kzwfHumJyYc              False             False                   False
# zUZ1z7FwLc8               True             False                   False
# 10L1hZ9qa58              False             False                   False
# N1vE8iiEg64              False             False                   False
# kJzGH0PVQHQ              False             False                   False
# il_pSa5l98w              False             False                   False
# 7MxiQ4v0EnE              False             False                   False
# c64I9HNpiOY              False             False                   False
# KObFEYCaRx8              False             False                   False
# g8QsfJhFpjY              False             False                   False
# 4du1KXBl4YU              False             False                   False
# zOOmEDwPJX0              False             False                   False
# Prb_osSVE0M               True             False                   False
# KHxdrECEsD0              False             False                   False
# so0ccfs-psI              False             False                   False
# 7gShaSuK_PY              False             False                   False
# ep3SLMuRbvg              False             False                   False
# ePO5M5DE01I              False             False                   False
# CLl1RbxDRAs              False             False                   False
# 1ZAPwfrtAFY              False             False                   False
# ZIHhuwvT7R0              False             False                   False
# Mqfh8_Uk1eM              False             False                   False
# 1kuJkA9usqg              False             False                   False
# 0SMKG3SRGzQ              False             False                   False
# bx-QX2ZPH60              False             False                   False
#
#              likes_log      label  dislikes_log  comment_log  num_tags  \
# video_id
# kzwfHumJyYc  10.433145  13.907477      6.683361     6.783325        15
# zUZ1z7FwLc8   6.601230  13.288051      6.807935     0.000000        19
# 10L1hZ9qa58   7.606885  13.068939      5.497168     5.010635        14
# N1vE8iiEg64  11.161295  14.032782      7.393263     7.895436        20
# kJzGH0PVQHQ   6.200509  13.047674      5.683580     4.204693        11
# il_pSa5l98w  11.498958  15.624892      8.339501     8.468843        22
# 7MxiQ4v0EnE  11.755699  15.559264      8.872768     8.995165        18
# c64I9HNpiOY  11.796140  16.175267      9.083983     9.291736        26
# KObFEYCaRx8   6.255750  11.680336      3.988984     3.178054        21
# g8QsfJhFpjY  10.998744  13.784052      7.343426     7.785305        23
# 4du1KXBl4YU   8.373554  13.357828      7.688913     7.962067        23
# zOOmEDwPJX0  10.399250  14.669120      6.566672     7.463937        22
# Prb_osSVE0M   6.575076  11.958162      3.988984     0.000000        20
# KHxdrECEsD0   7.867871  13.065611      5.525453     5.164786        12
# so0ccfs-psI  10.104835  13.636392      5.198497     6.388561        25
# 7gShaSuK_PY   5.476464  11.402351      4.094345     2.944439        28
# ep3SLMuRbvg  10.154946  12.749983      6.035481     7.962416        11
# ePO5M5DE01I  13.628413  17.395851     11.021837    11.524043        22
# CLl1RbxDRAs   9.551871  12.252956      6.107023     7.008505        30
# 1ZAPwfrtAFY  11.484403  14.698775      8.723719     9.449672         4
# ZIHhuwvT7R0   9.613202  14.645913      7.216709     6.817831        13
# Mqfh8_Uk1eM   9.159573  14.486885      6.844815     6.863803        29
# 1kuJkA9usqg   7.677864  12.866753      7.102499     6.568078        18
# 0SMKG3SRGzQ   6.378426  12.080923      3.970292     3.178054         3
# bx-QX2ZPH60   8.984192  12.382703      5.910797     7.150701         7
#
#              desc_len  len_title  ...  category_Sports  category_Trailers  \
# video_id                          ...
# kzwfHumJyYc       920         81  ...            False              False
# zUZ1z7FwLc8      2232         58  ...            False              False
# 10L1hZ9qa58       482         58  ...            False              False
# N1vE8iiEg64       263         30  ...            False              False
# kJzGH0PVQHQ       753         88  ...            False              False
# il_pSa5l98w       449         91  ...            False              False
# 7MxiQ4v0EnE      1411         96  ...            False              False
# c64I9HNpiOY      1299         96  ...            False              False
# KObFEYCaRx8       509         97  ...            False              False
# g8QsfJhFpjY       477         34  ...            False              False
# 4du1KXBl4YU        99         78  ...            False              False
# zOOmEDwPJX0      2093         83  ...            False              False
# Prb_osSVE0M       858         85  ...            False              False
# KHxdrECEsD0      1351         92  ...            False              False
# so0ccfs-psI      2387         88  ...            False              False
# 7gShaSuK_PY       171         85  ...            False              False
# ep3SLMuRbvg       248         35  ...            False              False
# ePO5M5DE01I       901         63  ...            False              False
# CLl1RbxDRAs       201         68  ...            False              False
# 1ZAPwfrtAFY       630         62  ...            False              False
# ZIHhuwvT7R0      1466         97  ...            False              False
# Mqfh8_Uk1eM       356         82  ...            False              False
# 1kuJkA9usqg       472         33  ...            False              False
# 0SMKG3SRGzQ       480         49  ...            False              False
# bx-QX2ZPH60       426         50  ...            False              False
#
#              category_Travel & Events  publish_weekday_1  publish_weekday_2  \
# video_id
# kzwfHumJyYc                     False              False              False
# zUZ1z7FwLc8                     False               True              False
# 10L1hZ9qa58                     False              False              False
# N1vE8iiEg64                     False              False              False
# kJzGH0PVQHQ                     False               True              False
# il_pSa5l98w                     False              False              False
# 7MxiQ4v0EnE                     False              False              False
# c64I9HNpiOY                     False              False              False
# KObFEYCaRx8                     False               True              False
# g8QsfJhFpjY                     False              False              False
# 4du1KXBl4YU                     False              False              False
# zOOmEDwPJX0                     False              False              False
# Prb_osSVE0M                     False               True              False
# KHxdrECEsD0                     False              False              False
# so0ccfs-psI                     False              False              False
# 7gShaSuK_PY                     False               True              False
# ep3SLMuRbvg                     False               True              False
# ePO5M5DE01I                     False              False               True
# CLl1RbxDRAs                     False              False              False
# 1ZAPwfrtAFY                     False               True              False
# ZIHhuwvT7R0                     False              False              False
# Mqfh8_Uk1eM                     False              False              False
# 1kuJkA9usqg                     False               True              False
# 0SMKG3SRGzQ                      True              False              False
# bx-QX2ZPH60                     False               True              False
#
#              publish_weekday_3  publish_weekday_4  publish_weekday_5  \
# video_id
# kzwfHumJyYc              False              False              False
# zUZ1z7FwLc8              False              False              False
# 10L1hZ9qa58              False              False              False
# N1vE8iiEg64              False              False              False
# kJzGH0PVQHQ              False              False              False
# il_pSa5l98w              False              False               True
# 7MxiQ4v0EnE              False              False              False
# c64I9HNpiOY              False              False              False
# KObFEYCaRx8              False              False              False
# g8QsfJhFpjY              False              False              False
# 4du1KXBl4YU              False              False              False
# zOOmEDwPJX0              False              False              False
# Prb_osSVE0M              False              False              False
# KHxdrECEsD0              False              False              False
# so0ccfs-psI              False              False              False
# 7gShaSuK_PY              False              False              False
# ep3SLMuRbvg              False              False              False
# ePO5M5DE01I              False              False              False
# CLl1RbxDRAs              False              False              False
# 1ZAPwfrtAFY              False              False              False
# ZIHhuwvT7R0              False              False              False
# Mqfh8_Uk1eM              False              False               True
# 1kuJkA9usqg              False              False              False
# 0SMKG3SRGzQ              False              False              False
# bx-QX2ZPH60              False              False              False
#
#              publish_weekday_6  publish_weekday_7
# video_id
# kzwfHumJyYc              False               True
# zUZ1z7FwLc8              False              False
# 10L1hZ9qa58              False               True
# N1vE8iiEg64              False               True
# kJzGH0PVQHQ              False              False
# il_pSa5l98w              False              False
# 7MxiQ4v0EnE               True              False
# c64I9HNpiOY               True              False
# KObFEYCaRx8              False              False
# g8QsfJhFpjY              False               True
# 4du1KXBl4YU              False               True
# zOOmEDwPJX0               True              False
# Prb_osSVE0M              False              False
# KHxdrECEsD0               True              False
# so0ccfs-psI              False               True
# 7gShaSuK_PY              False              False
# ep3SLMuRbvg              False              False
# ePO5M5DE01I              False              False
# CLl1RbxDRAs              False               True
# 1ZAPwfrtAFY              False              False
# ZIHhuwvT7R0               True              False
# Mqfh8_Uk1eM              False              False
# 1kuJkA9usqg              False              False
# 0SMKG3SRGzQ              False               True
# bx-QX2ZPH60              False              False
#
# [25 rows x 39 columns]

# %% [markdown]
# ## Scaling Dataset features

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features.values, label.values, test_size=0.2, random_state=0)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
print('check_data_split',[x_train.shape,x_test.shape,y_train.shape,y_test.shape])
# Out:
# check_data_split [(123653, 38), (30914, 38), (123653,), (30914,)]

# %% [markdown]
# ## Voting Regressor to compare different models
#
# * [skelarn Voting Regressor](https://scikit-learn.org/stable/modules/ensemble.html#voting-regressor)
# * [Linear Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
# * [Random Forest Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# * [Gradient Boosting Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html)
# *

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor

n_estimators=140 
# Training classifiers
grad_boosting_regressor = GradientBoostingRegressor(random_state=1,)
ada_boosting_regressor = AdaBoostRegressor(random_state=1, n_estimators=n_estimators)
random_forest_regressor = RandomForestRegressor(random_state=1)
bagging_regressor = BaggingRegressor(random_state=1, n_estimators=n_estimators)
linear_regr = LinearRegression()
voting_reg = VotingRegressor(estimators=[('gb', grad_boosting_regressor), ('rf', random_forest_regressor), ('lr', linear_regr), ('ada_b', ada_boosting_regressor), ('bagging_r', bagging_regressor)])

# %%
# Out:
# BaggingRegressor(n_estimators=140, random_state=1)

# %%
# Traing models - GradientBoostingRegressor, RandomForestRegressor, LinearRegression, AdaBoostRegressor, BaggingRegressor, VotingRegressor
grad_boosting_regressor.fit(x_train_Trans, y_train)
ada_boosting_regressor.fit(x_train_Trans, y_train)
bagging_regressor.fit(x_train_Trans, y_train)
random_forest_regressor.fit(x_train_Trans, y_train)
linear_regr.fit(x_train_Trans, y_train)
voting_reg.fit(x_train_Trans, y_train)
# Out:
# LinearRegression()

# %%
# gdb_prediction = grad_boosting_regressor.predict(x_test_Trans)
# rf_prediction = random_forest_regressor.predict(x_test_Trans)
# lg_prediction = linear_regr.predict(x_test_Trans)
# ada_b_prediction = ada_boosting_regressor.predict(x_test_Trans)
# bagging_r_prediction = bagging_regressor.predict(x_test_Trans)
voting_reg_prediction = voting_reg.predict(x_test_Trans)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

print('mean squared error', 'r2 score', 'explained variance score')
print(f'GradientBoostingRegressor',mean_squared_error(y_test, gdb_prediction),r2_score(y_test, gdb_prediction), explained_variance_score(y_test, gdb_prediction))
print('RandomForestRegressor',mean_squared_error(y_test, rf_prediction),r2_score(y_test, rf_prediction), explained_variance_score(y_test, rf_prediction))
print('LinearRegression',mean_squared_error(y_test, lg_prediction),r2_score(y_test, lg_prediction), explained_variance_score(y_test, lg_prediction))
print('AdaBoostRegressor',mean_squared_error(y_test, ada_b_prediction),r2_score(y_test, ada_b_prediction), explained_variance_score(y_test, ada_b_prediction))
print('BaggingRegressor',mean_squared_error(y_test, bagging_r_prediction),r2_score(y_test, bagging_r_prediction), explained_variance_score(y_test, bagging_r_prediction))
print('VotingRegressor',mean_squared_error(y_test, voting_reg_prediction),r2_score(y_test, voting_reg_prediction), explained_variance_score(y_test, voting_reg_prediction))
# Out:
# mean squared error r2 score explained variance score
# GradientBoostingRegressor 0.4712651148298537 0.8577461561568033 0.8577465641598396
# RandomForestRegressor 0.2251646577689804 0.9320328684272764 0.9321065460189157
# LinearRegression 0.5035593196983447 0.8479979812297007 0.8480011022780577
# AdaBoostRegressor 0.8288171687565475 0.7498171954836461 0.7526920840020509
# BaggingRegressor 0.22442478596725318 0.9322562026067751 0.9323297800928179
# VotingRegressor 0.34316753677343886 0.8964130811892407 0.8966199069012335

# %%
# from sklearn.model_selection import GridSearchCV
# 
# voting_reg = VotingRegressor(estimators=[('gb', grad_boosting_regressor), ('rf', random_forest_regressor), ('lr', linear_regr), ('ada_b', ada_boosting_regressor), ('bagging_r', bagging_regressor)])
# 
# grid = GridSearchCV(estimator=voting_reg, param_grid=, cv=5)
# grid = grid.fit(x_train_Trans, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 from sklearn.model_selection import GridSearchCV
#       3 voting_reg = VotingRegressor(estimators=[('gb', grad_boosting_regressor), ('rf', random_forest_regressor), ('lr', linear_regr), ('ada_b', ada_boosting_regressor), ('bagging_r', bagging_regressor)])
# ----> 5 grid = GridSearchCV(estimator=voting_reg, cv=5)
#       6 grid = grid.fit(x_train_Trans, y_train)
#
# TypeError: __init__() missing 1 required positional argument: 'param_grid'

# %%
bagging_r_prediction
# Out:
# array([12.67155305, 14.29352128, 10.05272472, ...,  9.92524016,
#        12.44956033, 11.80175256])

# %%
from  matplotlib import pyplot as plt

plt.figure(figsize=(14, 10))
# plt.plot(rf_prediction, "b^", label="RandomForestRegressor")
# plt.plot(lg_prediction, "ys", label="LinearRegression")
# plt.plot(gdb_prediction, "gd", label="GradientBoostingRegressor")
plt.plot(voting_reg_prediction, "gd", ms=10, label="VotingRegressor")
plt.plot(ada_b_prediction, "r*", label="AdaBoostRegressor")
plt.plot(bagging_r_prediction, "b*", label="BaggingRegressor")

plt.tick_params(axis="x", which="both", bottom=False, top=False, labelbottom=False)
plt.ylabel("predicted")
plt.xlabel("training samples")
plt.legend(loc="best")
plt.title("Regressor predictions and their average")

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
# Only tune the max depth of the trees in the RF hyperparameter.
grid = GridSearchCV(estimator=AdaBoostRegressor(), param_grid={'n_estimators':[140],'random_state':[5,20,42]},cv=5)
grid.fit(x_train_Trans, y_train)
grid.best_params_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("colorblind")

plt.figure()
plt.scatter(X, y, color=colors[0], label="training samples")
plt.plot(X, y_1, color=colors[1], label="n_estimators=1", linewidth=2)
plt.plot(X, y_2, color=colors[2], label="n_estimators=300", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Boosted Decision Tree Regression")
plt.legend()
plt.show()
