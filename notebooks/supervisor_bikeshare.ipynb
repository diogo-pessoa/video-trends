# %% [markdown]
# Supervisor Process to manage the workers.
# ---
# Diogo Pessoa
#
# Workers in this contexts are other Jupyter notebooks with smaller scope of work.

# %%
import os
import sys

from dotenv import load_dotenv

# Load environment variables from a .env file
load_dotenv()
images_path = os.getenv('IMAGES_PATH')
data_dir = os.getenv('DATA_COLLECTION_DIR')

# Loading local helper modules
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
"""
Local Dataset from local files (download if not present)
 :returns divvy_df: DataFrame
"""
# %run './data_collection.ipynb'
# Out:
# loading data to spark: divvy_df ['ride_id', 'rideable_type', 'started_at', 'ended_at', 'start_station_name', 'start_station_id', 'end_station_name', 'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'member_casual']

# %%
# features engineering
# %run './feature_engineering.ipynb'
"""
Local Dataset from local files (download if not present)
 :returns sampled_df_with_added_features: DataFrame, sampled_df_with_added_features_indexed: DataFrame
"""
# Out:
# +----------------+-------------+-------------------+-------------------+--------------------+----------------+--------------------+--------------+---------+----------+---------+----------+-------------+
# |         ride_id|rideable_type|         started_at|           ended_at|  start_station_name|start_station_id|    end_station_name|end_station_id|start_lat| start_lng|  end_lat|   end_lng|member_casual|
# +----------------+-------------+-------------------+-------------------+--------------------+----------------+--------------------+--------------+---------+----------+---------+----------+-------------+
# |000231C76163DBDC| classic_bike|2023-09-09 13:45:38|2023-09-09 14:22:19|Sheridan Rd & Loy...|          RP-009|     Montrose Harbor|  TA1308000012|42.001045|  -87.6612| 41.96398| -87.63818|       casual|
# |000247D0C95BE5FE| classic_bike|2023-12-21 08:06:27|2023-12-21 08:16:44|Sedgwick St & Hur...|    TA1307000062|Clark St & Randol...|  TA1305000030|41.894665|-87.638435|41.884575| -87.63189|       member|
# |00027333F0830BE3| classic_bike|2023-06-18 19:32:04|2023-06-18 20:07:03|Clark St & Wright...|    TA1305000014|Michigan Ave & Wa...|         13001|41.929546| -87.64312|41.883984| -87.62469|       member|
# |0002C287659534FC| classic_bike|2023-09-19 21:34:25|2023-09-19 21:48:40|Columbus Dr & Ran...|           13263|Clark St & Schill...|  TA1309000024|41.884727| -87.61952|41.907993|  -87.6315|       member|
# |0004EFB59AE940F8| classic_bike|2023-07-20 08:49:24|2023-07-20 09:12:02|Larrabee St & Web...|           13193|Clark St & Randol...|  TA1305000030| 41.92182| -87.64414|41.884575| -87.63189|       member|
# |00065C55F44F79DE|electric_bike|2023-09-25 13:25:40|2023-09-25 13:28:01|  Wells St & Polk St|          SL-011|Franklin St & Jac...|  TA1305000025|41.873123|  -87.6335| 41.87771| -87.63532|       member|
# |0006D7FA50B7C106| classic_bike|2023-05-06 17:33:42|2023-05-06 18:05:45|Peoria St & Jacks...|           13158|Wells St & Concor...|  TA1308000050| 41.87764| -87.64962|41.912132| -87.63466|       member|
# |000AE2594A7BBD51| classic_bike|2023-07-17 17:21:42|2023-07-17 17:32:14|Michigan Ave & Id...|    TA1305000010|Field Blvd & Sout...|         15534|41.876244| -87.62443| 41.88635|-87.617516|       member|
# |000F2DD700B5539F|electric_bike|2023-09-12 18:27:48|2023-09-12 18:33:38|University Ave & ...|    KA1503000071|  Shore Dr & 55th St|  TA1308000009| 41.79146| -87.60007| 41.79521| -87.58071|       member|
# |0011E750B52CF97C| classic_bike|2023-05-30 07:50:59|2023-05-30 07:59:06|Milwaukee Ave & W...|           13243|Ashland Ave & Div...|         13061|41.912617| -87.68139| 41.90345| -87.66775|       member|
# +----------------+-------------+-------------------+-------------------+--------------------+----------------+--------------------+--------------+---------+----------+---------+----------+-------------+
# only showing top 10 rows
# loaded sampled_df_with_added_features with 43492
#  and columns ['end_station_id', 'start_station_id', 'ride_id', 'rideable_type', 'started_at', 'ended_at', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'member_casual', 'start_station_name', 'end_station_name', 'day_period', 'week_day']
# loaded sampled_df_with_added_features_indexed with 43492
#  and columns ['end_station_id', 'start_station_id', 'ride_id', 'rideable_type', 'started_at', 'ended_at', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'member_casual', 'start_station_name', 'end_station_name', 'day_period', 'week_day', 'start_station_id_index', 'end_station_id_index', 'member_casual_index', 'day_period_index', 'week_day_index', 'rideable_type_index']
# '\nLocal Dataset from local files (download if not present)\n :returns sampled_df_with_added_features: DataFrame, sampled_df_with_added_features_indexed: DataFrame\n'

# %%
# Data Exploration
# %run './data_exploration.ipynb'

# %%
# Classification model training and evaluation
# %run './classification_model.ipynb'
# Out:
# 24/02/07 20:55:44 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# Model accuracy: 0.62
# Model accuracy: 0.64
# Model accuracy: 0.62
# Model accuracy: 0.65
# Model accuracy: 0.63
# Model accuracy: 0.65

# %%
# sillhouette index score
# %run './sillhouette_score.ipynb'
# Out:
# The optimal number of clusters k is: 3

# %%
# Kmeans clustering
# %run './clustering_analysis.ipynb'
# Out:
# 24/02/07 21:34:26 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
